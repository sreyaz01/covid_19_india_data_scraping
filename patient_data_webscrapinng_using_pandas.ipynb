# %% [markdown]
# # Patient Data web Scraping

# %% [markdown]
# <a href="https://github.com/sreyaz01/covid_19_india_data_scraping"><img src="https://i.ibb.co/B3vvzTy/0-s-Y-XTIBzlfd2zskq.png" alt="0-s-Y-XTIBzlfd2zskq" border="0"></a>

# %% [markdown]
# ### <li>Data Source<br>
#
# https://api.covid19india.org/

# %% [raw]
# Due to the growing size of the raw data, and the fact that regions like DL, MH, TG are only providing district level information, we have made a change in our data collection. Now, raw data is available in three parts :
#
# api.covid19india.org/raw_data1.json (Data till EoD Apr 19th)
# api.covid19india.org/raw_data2.json (Data till EoD Apr 26th)
# api.covid19india.org/raw_data3.json (Live 🚀)

# %%
# libraries
import requests 
import pandas as pd
import numpy as np
import json

# Hide warnings
import warnings
warnings.filterwarnings('ignore')

print('Pandas Version',pd.__version__)
# Out:
# Pandas Version 1.0.1

# %% [markdown]
# ## Scraping

# %% [markdown]
# #### <li>Till Apr 19

# %%
link = 'https://api.covid19india.org/raw_data1.json'
# getting response from the web page
web = requests.get(link)

# getting contents from the response
content = web.content

# parse the json file
parsed = json.loads(content)
#parsed

#contents inside json file
parsed.keys()
# Out:
# dict_keys(['raw_data'])

# %% [markdown]
# #### <li>Saving to DataFrame

# %%
df1 = pd.DataFrame(parsed['raw_data'])
print(df1.shape)
df1.head()
# Out:
# (17306, 20)
#   agebracket                                 backupnotes  \
# 0         20                          Student from Wuhan
# 1                                     Student from Wuhan
# 2                                     Student from Wuhan
# 3         45         Travel history to Italy and Austria
# 4         24  Travel history to Dubai, Singapore contact
#
#   contractedfromwhichpatientsuspected currentstatus dateannounced  \
# 0                                         Recovered    30/01/2020
# 1                                         Recovered    02/02/2020
# 2                                         Recovered    03/02/2020
# 3                                         Recovered    02/03/2020
# 4                                         Recovered    02/03/2020
#
#                detectedcity detecteddistrict detectedstate estimatedonsetdate  \
# 0                  Thrissur         Thrissur        Kerala
# 1                 Alappuzha        Alappuzha        Kerala
# 2                 Kasaragod        Kasaragod        Kerala
# 3  East Delhi (Mayur Vihar)       East Delhi         Delhi
# 4                 Hyderabad        Hyderabad     Telangana
#
#   gender nationality                                              notes  \
# 0      F       India                               Travelled from Wuhan
# 1              India                               Travelled from Wuhan
# 2              India                               Travelled from Wuhan
# 3      M       India                      Travelled from Austria, Italy
# 4      M       India  Travelled from Dubai to Bangalore on 20th Feb,...
#
#   patientnumber                                            source1  \
# 0             1  https://twitter.com/vijayanpinarayi/status/122...
# 1             2  https://www.indiatoday.in/india/story/kerala-r...
# 2             3  https://www.indiatoday.in/india/story/kerala-n...
# 3             4  https://www.indiatoday.in/india/story/not-a-ja...
# 4             5  https://www.deccanherald.com/national/south/qu...
#
#                                              source2  \
# 0  https://weather.com/en-IN/india/news/news/2020...
# 1  https://weather.com/en-IN/india/news/news/2020...
# 2  https://twitter.com/ANI/status/122422148580539...
# 3  https://economictimes.indiatimes.com/news/poli...
# 4  https://www.indiatoday.in/india/story/coronavi...
#
#                                              source3 statecode  \
# 0                                                           KL
# 1                                                           KL
# 2  https://weather.com/en-IN/india/news/news/2020...        KL
# 3                                                           DL
# 4  https://www.thehindu.com/news/national/coronav...        TG
#
#   statepatientnumber statuschangedate typeoftransmission
# 0           KL-TS-P1       14/02/2020           Imported
# 1           KL-AL-P1       14/02/2020           Imported
# 2           KL-KS-P1       14/02/2020           Imported
# 3              DL-P1       15/03/2020           Imported
# 4              TS-P1       02/03/2020           Imported

# %%
print(len(df1.columns))
df1.columns
# Out:
# 20
# Index(['agebracket', 'backupnotes', 'contractedfromwhichpatientsuspected',
#        'currentstatus', 'dateannounced', 'detectedcity', 'detecteddistrict',
#        'detectedstate', 'estimatedonsetdate', 'gender', 'nationality', 'notes',
#        'patientnumber', 'source1', 'source2', 'source3', 'statecode',
#        'statepatientnumber', 'statuschangedate', 'typeoftransmission'],
#       dtype='object')

# %% [markdown]
# #### <li>Till Apr 26

# %%
link = 'https://api.covid19india.org/raw_data2.json'
# getting response from the web page
web = requests.get(link)

# getting contents from the response
content = web.content

# parse the json file
parsed = json.loads(content)
#parsed

#contents inside json file
parsed.keys()
# Out:
# dict_keys(['raw_data'])

# %% [markdown]
# #### <li>Saving to DataFrame

# %%
df2 = pd.DataFrame(parsed['raw_data'])
print(df2.shape)
df2.head()
# Out:
# (10585, 20)
#   agebracket backupnotes contractedfromwhichpatientsuspected currentstatus  \
# 0         48                                                  Hospitalized
# 1         55                                                  Hospitalized
# 2         57                                                  Hospitalized
# 3         58                                                  Hospitalized
# 4         66                                                  Hospitalized
#
#   dateannounced detectedcity detecteddistrict detectedstate  \
# 0    20/04/2020                       Bhadrak        Odisha
# 1    20/04/2020                       Bhadrak        Odisha
# 2    20/04/2020                       Bhadrak        Odisha
# 3    20/04/2020                       Bhadrak        Odisha
# 4    20/04/2020                       Bhadrak        Odisha
#
#   estimatedonsetdate gender nationality            notes patientnumber  \
# 0                         M              Details awaited         17307
# 1                         M              Details awaited         17308
# 2                         M              Details awaited         17309
# 3                         M              Details awaited         17310
# 4                         M              Details awaited         17311
#
#                                              source1 source2 source3  \
# 0  https://twitter.com/the_hindu/status/125205985...
# 1  https://twitter.com/the_hindu/status/125205985...
# 2  https://twitter.com/the_hindu/status/125205985...
# 3  https://twitter.com/the_hindu/status/125205985...
# 4  https://twitter.com/the_hindu/status/125205985...
#
#   statecode statepatientnumber statuschangedate typeoftransmission
# 0        OR                          20/04/2020
# 1        OR                          20/04/2020
# 2        OR                          20/04/2020
# 3        OR                          20/04/2020
# 4        OR                          20/04/2020

# %%
print(len(df2.columns))
df2.columns
# Out:
# 20
# Index(['agebracket', 'backupnotes', 'contractedfromwhichpatientsuspected',
#        'currentstatus', 'dateannounced', 'detectedcity', 'detecteddistrict',
#        'detectedstate', 'estimatedonsetdate', 'gender', 'nationality', 'notes',
#        'patientnumber', 'source1', 'source2', 'source3', 'statecode',
#        'statepatientnumber', 'statuschangedate', 'typeoftransmission'],
#       dtype='object')

# %% [markdown]
# #### <li> Live Data

# %%
link = 'https://api.covid19india.org/raw_data3.json'
# getting response from the web page
web = requests.get(link)

# getting contents from the response
content = web.content

# parse the json file
parsed = json.loads(content)
#parsed

#contents inside json file
parsed.keys()
# Out:
# dict_keys(['raw_data'])

# %%
df3 = pd.DataFrame(parsed['raw_data'])
print(df3.shape)
df3.head()
# Out:
# (5057, 20)
#   agebracket contractedfromwhichpatientsuspected currentstatus dateannounced  \
# 0                                                 Hospitalized    27/04/2020
# 1                                                 Hospitalized    27/04/2020
# 2                                                 Hospitalized    27/04/2020
# 3         28                                          Deceased    27/04/2020
# 4                                                 Hospitalized    27/04/2020
#
#   detectedcity detecteddistrict detectedstate entryid gender nationality  \
# 0                                 West Bengal       1
# 1                      Bhilwara     Rajasthan       2
# 2                        Jaipur     Rajasthan       3
# 3     Surajpol           Jaipur     Rajasthan       4      M
# 4                     Jaisalmer     Rajasthan       5
#
#              notes numcases patientnumber  \
# 0  Details awaited       38         27892
# 1  Details awaited        2         27893
# 2  Details awaited        9         27894
# 3  Details awaited        1         27895
# 4  Details awaited        1         27896
#
#                                              source1 source2 source3  \
# 0                                       mohfw.gov.in
# 1  https://twitter.com/ANI/status/125461859651442...
# 2  https://twitter.com/ANI/status/125461859651442...
# 3  https://twitter.com/ANI/status/125461859651442...
# 4  https://twitter.com/ANI/status/125461859651442...
#
#   statecode statepatientnumber statuschangedate typeoftransmission
# 0        WB
# 1        RJ
# 2        RJ
# 3        RJ
# 4        RJ

# %%
print(len(df3.columns))
df3.columns
# Out:
# 20
# Index(['agebracket', 'contractedfromwhichpatientsuspected', 'currentstatus',
#        'dateannounced', 'detectedcity', 'detecteddistrict', 'detectedstate',
#        'entryid', 'gender', 'nationality', 'notes', 'numcases',
#        'patientnumber', 'source1', 'source2', 'source3', 'statecode',
#        'statepatientnumber', 'statuschangedate', 'typeoftransmission'],
#       dtype='object')

# %% [markdown]
# ## Merging DataFrames

# %% [markdown]
# #### Columns Deffrences

# %%
np.setdiff1d(df1.columns,df2.columns)
# Out:
# array([], dtype=object)

# %%
np.setdiff1d(df2.columns,df3.columns)
# Out:
# array(['backupnotes', 'estimatedonsetdate'], dtype=object)

# %% [markdown]
# #### Data Cleaning

# %%
df3 = df3.drop(['entryid', 'numcases'], axis = 1)

# %%
df = pd.concat([df1, df2, df3])

print(df.shape)
df.head(2)
# Out:
# (32948, 20)
#   agebracket         backupnotes contractedfromwhichpatientsuspected  \
# 0         20  Student from Wuhan
# 1             Student from Wuhan
#
#   currentstatus dateannounced detectedcity detecteddistrict detectedstate  \
# 0     Recovered    30/01/2020     Thrissur         Thrissur        Kerala
# 1     Recovered    02/02/2020    Alappuzha        Alappuzha        Kerala
#
#   estimatedonsetdate gender nationality                 notes patientnumber  \
# 0                         F       India  Travelled from Wuhan             1
# 1                                 India  Travelled from Wuhan             2
#
#                                              source1  \
# 0  https://twitter.com/vijayanpinarayi/status/122...
# 1  https://www.indiatoday.in/india/story/kerala-r...
#
#                                              source2 source3 statecode  \
# 0  https://weather.com/en-IN/india/news/news/2020...                KL
# 1  https://weather.com/en-IN/india/news/news/2020...                KL
#
#   statepatientnumber statuschangedate typeoftransmission
# 0           KL-TS-P1       14/02/2020           Imported
# 1           KL-AL-P1       14/02/2020           Imported

# %%
df.columns
# Out:
# Index(['agebracket', 'backupnotes', 'contractedfromwhichpatientsuspected',
#        'currentstatus', 'dateannounced', 'detectedcity', 'detecteddistrict',
#        'detectedstate', 'estimatedonsetdate', 'gender', 'nationality', 'notes',
#        'patientnumber', 'source1', 'source2', 'source3', 'statecode',
#        'statepatientnumber', 'statuschangedate', 'typeoftransmission'],
#       dtype='object')

# %% [markdown]
# ## Final DataFrame Prepration

# %% [markdown]
# ### Data cleaning and transformations

# %%
df['p_id'] = df['patientnumber'].apply(lambda x : 'P'+str(x))
df.columns
# Out:
# Index(['agebracket', 'backupnotes', 'contractedfromwhichpatientsuspected',
#        'currentstatus', 'dateannounced', 'detectedcity', 'detecteddistrict',
#        'detectedstate', 'estimatedonsetdate', 'gender', 'nationality', 'notes',
#        'patientnumber', 'source1', 'source2', 'source3', 'statecode',
#        'statepatientnumber', 'statuschangedate', 'typeoftransmission', 'p_id'],
#       dtype='object')

# %% [markdown]
# #### Rearranging and Renaming Columns

# %%
# order of columns
cols = ['patientnumber', 'p_id', 'statepatientnumber', 
        'dateannounced', 'agebracket', 'gender', 
        'detectedcity', 'detecteddistrict', 'detectedstate', 'statecode', 'nationality',
        'typeoftransmission', 'contractedfromwhichpatientsuspected',
        'statuschangedate', 'currentstatus', 'estimatedonsetdate',
        'source1', 'source2', 'source3', 'notes', 'backupnotes']

# rearrange columns
df = df[cols]

# rename columns
df.columns = ['patient_number', 'p_id', 'state_patient_number', 
              'date_announced', 'age_bracket', 'gender', 
              'detected_city', 'detected_district', 'detected_state', 'state_code', 'nationality',
              'type_of_transmission', 'contracted_from_which_patient_suspected',
              'status_change_date', 'current_status', 'estimated_onset_date',
              'source1', 'source2', 'source3', 'notes', 'backup_notes']

# dataframe shape
df.shape
# Out:
# (32948, 21)

# %%
#sampling DataFrame
df.sample(3)
# Out:
#       patient_number    p_id state_patient_number date_announced age_bracket  \
# 10507          10508  P10508                          14/04/2020
# 11926          11927  P11927                          15/04/2020
# 3655            3656   P3656                          04/04/2020
#
#       gender detected_city detected_district detected_state state_code  ...  \
# 10507                                           West Bengal         WB  ...
# 11926                                 Mumbai    Maharashtra         MH  ...
# 3655                                  Mumbai    Maharashtra         MH  ...
#
#       type_of_transmission contracted_from_which_patient_suspected  \
# 10507
# 11926
# 3655
#
#       status_change_date current_status estimated_onset_date  \
# 10507         14/04/2020   Hospitalized
# 11926         15/04/2020   Hospitalized
# 3655                       Hospitalized
#
#                                                  source1  \
# 10507                                       mohfw.gov.in
# 11926  https://twitter.com/ANI/status/125043632276379...
# 3655   https://twitter.com/rajeshtope11/status/124648...
#
#                                                  source2 source3  \
# 10507
# 11926  https://twitter.com/rajeshtope11/status/125044...
# 3655
#
#                  notes backup_notes
# 10507  Details awaited
# 11926  Details awaited
# 3655
#
# [3 rows x 21 columns]

# %% [markdown]
# #### Missing Values or Empty String Handling

# %%
for i in df.columns:
    filt = (df[i] == '' ) # creating empty string search filter
    empty = df.loc[filt].shape
    print(i, '------\t', empty[0])
# Out:
# patient_number ------	 570
# p_id ------	 0
# state_patient_number ------	 28000
# date_announced ------	 67
# age_bracket ------	 28225
# gender ------	 25794
# detected_city ------	 30344
# detected_district ------	 7784
# detected_state ------	 74
# state_code ------	 77
# nationality ------	 30241
# type_of_transmission ------	 29958
# contracted_from_which_patient_suspected ------	 31186
# status_change_date ------	 5168
# current_status ------	 69
# estimated_onset_date ------	 27891
# source1 ------	 487
# source2 ------	 29037
# source3 ------	 32469
# notes ------	 4773
# backup_notes ------	 27530

# %%
# replacing empty strings with np.nan
# ==================================-

print(df.shape)

df = df.replace(r'', np.nan, regex=True)
df.sample(5)
# Out:
# (32948, 21)
#      patient_number    p_id state_patient_number date_announced age_bracket  \
# 2639          19946  P19946                  NaN     21/04/2020         NaN
# 9255           9256   P9256              KA-P235     13/04/2020          74
# 5004          22311  P22311                  NaN     23/04/2020         NaN
# 7215          24522  P24522                  NaN     25/04/2020         NaN
# 5122           5123   P5123                  NaN     07/04/2020         NaN
#
#      gender detected_city detected_district detected_state state_code  ...  \
# 2639    NaN           NaN         Hyderabad      Telangana         TG  ...
# 9255      F      Hubballi           Dharwad      Karnataka         KA  ...
# 5004    NaN           NaN               NaN    Maharashtra         MH  ...
# 7215    NaN           NaN           Dholpur      Rajasthan         RJ  ...
# 5122    NaN           NaN            Mumbai    Maharashtra         MH  ...
#
#      type_of_transmission contracted_from_which_patient_suspected  \
# 2639                  NaN                                     NaN
# 9255                Local                                   P6266
# 5004                  NaN                                     NaN
# 7215                  NaN                                     NaN
# 5122                  NaN                                     NaN
#
#      status_change_date current_status estimated_onset_date  \
# 2639         21/04/2020   Hospitalized                  NaN
# 9255         13/04/2020   Hospitalized                  NaN
# 5004         23/04/2020   Hospitalized                  NaN
# 7215         25/04/2020   Hospitalized                  NaN
# 5122         07/04/2020   Hospitalized                  NaN
#
#                                                 source1  \
# 2639  https://twitter.com/TelanganaHealth/status/125...
# 9255      https://t.me/Karnataka_KoViD19_Broadcast/1933
# 5004  https://twitter.com/ANI/status/125334219922530...
# 7215  https://twitter.com/PIBJaipur/status/125389818...
# 5122  https://twitter.com/rajeshtope11/status/124755...
#
#                                                 source2 source3  \
# 2639                                                NaN     NaN
# 9255  https://twitter.com/DHFWKA/status/124960075639...     NaN
# 5004                                                NaN     NaN
# 7215                                                NaN     NaN
# 5122                                                NaN     NaN
#
#                    notes backup_notes
# 2639     Details awaited          NaN
# 9255  Contact of KA-P194          NaN
# 5004     Details awaited          NaN
# 7215     Details awaited          NaN
# 5122     Details awaited          NaN
#
# [5 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# patient_number                               570
# p_id                                           0
# state_patient_number                       28000
# date_announced                                67
# age_bracket                                28225
# gender                                     25794
# detected_city                              30344
# detected_district                           7784
# detected_state                                74
# state_code                                    77
# nationality                                30241
# type_of_transmission                       29958
# contracted_from_which_patient_suspected    31186
# status_change_date                          5168
# current_status                                69
# estimated_onset_date                       32948
# source1                                      487
# source2                                    29037
# source3                                    32469
# notes                                       4773
# backup_notes                               32587
# dtype: int64

# %%
# droping empty rows (row with just row number but without patient entry


print(df.shape)

df.dropna(subset=['detected_state'], inplace=True)

print(df.shape)
df.isnull().sum()
# Out:
# (32948, 21)
# (32874, 21)
# patient_number                               502
# p_id                                           0
# state_patient_number                       27926
# date_announced                                 0
# age_bracket                                28151
# gender                                     25720
# detected_city                              30270
# detected_district                           7712
# detected_state                                 0
# state_code                                     3
# nationality                                30167
# type_of_transmission                       29884
# contracted_from_which_patient_suspected    31112
# status_change_date                          5094
# current_status                                 2
# estimated_onset_date                       32874
# source1                                      420
# source2                                    28963
# source3                                    32396
# notes                                       4705
# backup_notes                               32513
# dtype: int64

# %%
df.to_csv(r'C:\Users\sreya\Desktop\Pythone_File\COVID-19_INDIA\input\covid19-corona-virus-india-dataset\patients_data.csv', index=False)

# %% [markdown]
# # State Testing Data

# %% [markdown]
# ### Web Scarping

# %%
link = 'https://api.covid19india.org/state_test_data.json'
# getting response from the web page
web = requests.get(link)

# getting contents from the response
content = web.content

# parse the json file
parsed = json.loads(content)
#parsed

#contents inside json file
parsed.keys()
# Out:
# dict_keys(['states_tested_data'])

# %% [markdown]
# ### Saving to DataFrame

# %%
st = pd.DataFrame(parsed['states_tested_data'])
print(st.shape)
st.head(3)
# Out:
# (761, 21)
#   negative numcallsstatehelpline numicubeds numisolationbeds numventilators  \
# 0     1210                                                50
# 1                            280                          50
# 2                            298                          50
#
#   populationsourcecovid19india positive                               source  \
# 0                       397000       12         https://t.me/indiacovid/2550
# 1                                    27  https://t.me/indiacovid/3147?single
# 2                                    33  https://t.me/indiacovid/3365?single
#
#   source2                        state  ... testpositivityrate  \
# 0          Andaman and Nicobar Islands  ...              0.86%
# 1          Andaman and Nicobar Islands  ...              1.01%
# 2          Andaman and Nicobar Islands  ...              1.16%
#
#   testspermillion testsperthousand totalpeopleinquarantine  \
# 0            3534             3.53
# 1            6748             6.75
# 2            7174             7.17
#
#   totalpeoplereleasedfromquarantine totaltested unconfirmed   updatedon  \
# 0                                          1403         181  17/04/2020
# 1                                          2679         246  24/04/2020
# 2                                          2848         106  27/04/2020
#
#   _d415a   _d5fpr
# 0    NaN      NaN
# 1   1000  1000000
# 2    NaN      NaN
#
# [3 rows x 21 columns]

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 761 entries, 0 to 760
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   negative                           761 non-null    object
#  1   numcallsstatehelpline              761 non-null    object
#  2   numicubeds                         761 non-null    object
#  3   numisolationbeds                   761 non-null    object
#  4   numventilators                     761 non-null    object
#  5   populationsourcecovid19india       761 non-null    object
#  6   positive                           761 non-null    object
#  7   source                             761 non-null    object
#  8   source2                            761 non-null    object
#  9   state                              761 non-null    object
#  10  tags                               761 non-null    object
#  11  testpositivityrate                 761 non-null    object
#  12  testspermillion                    761 non-null    object
#  13  testsperthousand                   761 non-null    object
#  14  totalpeopleinquarantine            761 non-null    object
#  15  totalpeoplereleasedfromquarantine  761 non-null    object
#  16  totaltested                        761 non-null    object
#  17  unconfirmed                        761 non-null    object
#  18  updatedon                          761 non-null    object
#  19  _d415a                             1 non-null      object
#  20  _d5fpr                             1 non-null      object
# dtypes: object(21)
# memory usage: 125.0+ KB

# %% [markdown]
# ####  Rearranging and Renaming Columns

# %%
cols = ['state', 'updatedon', 'totaltested', 'testspermillion', 'testsperthousand',
        'positive', 'negative', 'unconfirmed', 'testpositivityrate',
        'totalpeopleinquarantine', 'totalpeoplereleasedfromquarantine', 'populationsourcecovid19india',
        'numicubeds', 'numisolationbeds', 'numventilators', 'numcallsstatehelpline',
        '_d415a', '_d5fpr', 'source', 'source2']

st = st[cols]

st.head()
# Out:
#                          state   updatedon totaltested testspermillion  \
# 0  Andaman and Nicobar Islands  17/04/2020        1403            3534
# 1  Andaman and Nicobar Islands  24/04/2020        2679            6748
# 2  Andaman and Nicobar Islands  27/04/2020        2848            7174
# 3  Andaman and Nicobar Islands  01/05/2020        3754            9456
# 4               Andhra Pradesh  02/04/2020        1800              34
#
#   testsperthousand positive negative unconfirmed testpositivityrate  \
# 0             3.53       12     1210         181              0.86%
# 1             6.75       27                  246              1.01%
# 2             7.17       33                  106              1.16%
# 3             9.46       33                  199              0.88%
# 4             0.03      132     1175         493              7.33%
#
#   totalpeopleinquarantine totalpeoplereleasedfromquarantine  \
# 0
# 1
# 2
# 3                     643
# 4                     179
#
#   populationsourcecovid19india numicubeds numisolationbeds numventilators  \
# 0                       397000                          50
# 1                                                       50
# 2                                                       50
# 3                                                       50
# 4                     52221000       2680            23479            330
#
#   numcallsstatehelpline _d415a   _d5fpr  \
# 0                          NaN      NaN
# 1                   280   1000  1000000
# 2                   298    NaN      NaN
# 3                   340    NaN      NaN
# 4                          NaN      NaN
#
#                                               source source2
# 0                       https://t.me/indiacovid/2550
# 1                https://t.me/indiacovid/3147?single
# 2                https://t.me/indiacovid/3365?single
# 3                       https://t.me/indiacovid/3781
# 4  https://twitter.com/ArogyaAndhra/status/124558...

# %%
st.to_csv(r'C:\Users\sreya\Desktop\Pythone_File\COVID-19_INDIA\input\covid19-corona-virus-india-dataset\state_testing.csv', index=False)

# %% [markdown]
# # Zones Distribution

# %% [markdown]
# ### Web Scarping

# %%
# get response from the web page
response = requests.get('https://api.covid19india.org/zones.json')

# get contents from the response
content = response.content

# parse the json file
parsed = json.loads(content)

# keys
parsed.keys()
# Out:
# dict_keys(['zones'])

# %% [markdown]
# ### Saving to DataFrame

# %%
zone = pd.DataFrame(parsed['zones'])
zone.head(3)
# Out:
#                    district                 districtcode lastupdated  \
# 0                  Nicobars                  AN_Nicobars  01/05/2020
# 1  North and Middle Andaman  AN_North and Middle Andaman  01/05/2020
# 2             South Andaman             AN_South Andaman  01/05/2020
#
#                                               source  \
# 0  https://www.facebook.com/airnewsalerts/photos/...
# 1  https://www.facebook.com/airnewsalerts/photos/...
# 2  https://www.facebook.com/airnewsalerts/photos/...
#
#                          state statecode   zone
# 0  Andaman and Nicobar Islands        AN  Green
# 1  Andaman and Nicobar Islands        AN  Green
# 2  Andaman and Nicobar Islands        AN    Red

# %%
zone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   district      742 non-null    object
#  1   districtcode  742 non-null    object
#  2   lastupdated   742 non-null    object
#  3   source        742 non-null    object
#  4   state         742 non-null    object
#  5   statecode     742 non-null    object
#  6   zone          742 non-null    object
# dtypes: object(7)
# memory usage: 40.7+ KB

# %%
zone.to_csv(r'C:\Users\sreya\Desktop\Pythone_File\COVID-19_INDIA\input\covid19-corona-virus-india-dataset\zones.csv', index=False)
